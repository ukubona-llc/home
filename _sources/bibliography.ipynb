# %% [markdown]
# # Bibliography 📚✍️🧭
# *“To cite is to remember. To remember is to root.”*
#
# ---
#
# This bibliography collects the sources, signals, and spirits that shaped the content, design philosophy, and epistemic structure of Ukubona.
#
# It includes:
#
# - Peer-reviewed clinical research
# - Epidemiologic datasets
# - Philosophical and poetic references
# - Mythological and symbolic frameworks
# - Open-source software and modeling practices
#
# ---
#
# ## 🔬 Clinical & Epidemiologic Foundations
#
# 1. Muzaale AD, Massie AB, Wang M-C, et al. *Risk of End-Stage Renal Disease Following Live Kidney Donation.* JAMA. 2014;311(6):579–586.
#
# 2. Segev DL, Muzaale AD, Caffo BS, et al. *Perioperative mortality and long-term survival following live kidney donation.* JAMA. 2010;303(10):959–966.
#
# 3. KDIGO. *Clinical Practice Guideline for the Evaluation and Care of Living Kidney Donors.* Kidney Int Suppl. 2017.
#
# 4. U.S. Renal Data System (USRDS). *Annual Data Report.* Available: https://www.usrds.org
#
# 5. National Health and Nutrition Examination Survey (NHANES). CDC.
#
# 6. Scientific Registry of Transplant Recipients (SRTR). https://srtr.transplant.hrsa.gov
#
# ---
#
# ## 🧠 Epistemology, Risk, and Power
#
# 7. Foucault M. *The Birth of the Clinic.*
# 8. Haraway D. *Situated Knowledges: The Science Question in Feminism and the Privilege of Partial Perspective.*
# 9. Bourdieu P. *La Distinction.*
# 10. Tufte E. *The Visual Display of Quantitative Information.*
# 11. Benjamin R. *Race After Technology.*
# 12. Eubanks V. *Automating Inequality.*
#
# ---
#
# ## 🎭 Myth, Symbol, and Metaphor
#
# 13. Nietzsche F. *The Birth of Tragedy.*
# 14. Mbiti JS. *African Religions and Philosophy.*
# 15. Hesiod. *Theogony.*
# 16. “The Sea, the Ship, the Island” — Personal motif of Abimereki Muzaale, adapted from ancestral metaphor and navigational theology.
#
# ---
#
# ## 💻 Software, Visualization, and Modeling
#
# 17. Matplotlib & NumPy – Python scientific stack
# 18. NetworkX – Ecosystem diagrams
# 19. Jupyter Book – Open scientific publishing
# 20. scikit-survival – Survival analysis modeling
# 21. GitHub Pages – Hosting and continuous deployment
# 22. Ukubona Public Repository – [Coming Soon...]
#
# ---
#
# ## 🪡 Quotes, Epigraphs & Links (Selected)
#
# - *“To see clearly is to act wisely.”* – African proverb
# - *“What is lost when life gives?”* – Adapted poetic prompt
# - SRTR Reference: https://srtr.transplant.hrsa.gov
# - Gutenberg Mask Quote: [The Truth of Masks 🎭](https://www.gutenberg.org/cache/epub/887/pg887-images.html#page221)
#
# ---
#
# ## 🧾 Notes
#
# - All patient risk figures derived from de-identified, linked national datasets.
# - Visualizations and apps are demonstrative, not diagnostic.
# - Every attempt was made to credit sources where appropriate.
# - This bibliography will evolve as the platform grows.
#
# ---
#
# *Built by Ukubona LLC – for clarity, discernment, and navigational care.*
